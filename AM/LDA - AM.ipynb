# %% [markdown]
# # LDA para o Referencial Curricular Amazonense para Educação Infantil e Ensino Fundamental:

# %% [markdown]
# ## Importação das bibliotecas:

# %%
# Para ler o PDF:
import PyPDF2

# Para analisar o layout do PDF e extrair o texto:
from pdfminer.high_level import extract_pages, extract_text
from pdfminer.layout import LTTextContainer, LTChar, LTRect, LTFigure

# Para extrair textos de tabelas em PDF:
import pdfplumber

# Para extrair as imagens dos PDFs:
from PIL import Image
from pdf2image import convert_from_path

# Para fazer Reconhecimento Ótico de Caracteres (OCR) para extrair textos das imagens:
import pytesseract

# Para remover os arquivos adicionais criados:
import os

# Para manipulação e análise dos dados:
import pandas as pd
import numpy as np
from collections import Counter

# Para acompanhar a execução dos códigos:
from tqdm import tqdm

# Para análise dos dados textuais:
import re
import nltk
import spacy
import gensim
from gensim import corpora
from gensim.models import LdaModel
from gensim.utils import simple_preprocess
from gensim.models.coherencemodel import CoherenceModel

# Para visualizações:
import pyLDAvis
import pyLDAvis.gensim
import pyLDAvis.gensim_models as gensimvis
from nltk import FreqDist
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# Download do modelo para língua portuguesa:
spacy.cli.download("pt_core_news_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')

# %%
# Carregamento do modelo:
nlp = spacy.load('pt_core_news_lg')

# %% [markdown]
# ##  Rotacionar algumas páginas do PDF para que a extração das informações funcione:

# %%
def rotacionar_e_adicionar_paginas(input_path, output_path, intervalos_paginas, graus_de_rotacao):
    # Abre o arquivo PDF original em modo de leitura binária
    with open(input_path, 'rb') as arquivo_original:
        leitor_pdf = PyPDF2.PdfReader(arquivo_original)
        
        # Cria um escritor para o novo arquivo PDF
        escritor_pdf = PyPDF2.PdfWriter()

        # Itera sobre as páginas do PDF original
        for numero_pagina in range(len(leitor_pdf.pages)):
            pagina = leitor_pdf.pages[numero_pagina]
            
            # Verifica se a página atual deve ser rotacionada
            if any(inicio <= numero_pagina + 1 <= fim for inicio, fim in intervalos_paginas):
                pagina = pagina.rotate(graus_de_rotacao)
            
            # Adiciona a página ao novo arquivo
            escritor_pdf.add_page(pagina)

        # Cria um novo arquivo PDF em modo de escrita binária
        with open(output_path, 'wb') as novo_arquivo:
            # Escreve o conteúdo do escritor no novo arquivo
            escritor_pdf.write(novo_arquivo)

if __name__ == "__main__":
    # Especifica o caminho do arquivo PDF original e do novo arquivo
    arquivo_original_path = r"C:\Users\hugob\Dropbox\Hugo_Bovareto\Dissertação PROFIAP\LDA\AM\AM_curriculo_EIEF.pdf"
    novo_arquivo_path = r"C:\Users\hugob\Dropbox\Hugo_Bovareto\Dissertação PROFIAP\LDA\AM\AM_curriculo_EIEF_com rotacoes.pdf"
    
    # Especifica os intervalos de páginas a serem rotacionados e o grau de rotação (90 para rotação de 90 graus no sentido horário)
    intervalos_paginas = [(68, 154), (326, 554), (560, 581), (593, 612), (617, 663), (674, 726), (731, 767), (774, 800), (807, 820), (825, 840), (845, 854), (973, 1141), (1147, 1183), (1192, 1212), (1217, 1246), (1257, 1275), (1282, 1313), (1319, 1340), (1348, 1389), (1399, 1444), (1450, 1457)]
    graus_de_rotacao = 90

    # Chama a função para realizar a rotação e criar o novo arquivo PDF
    rotacionar_e_adicionar_paginas(arquivo_original_path, novo_arquivo_path, intervalos_paginas, graus_de_rotacao)

# %% [markdown]
# ## 1. Extração das informações do PDF:

# %%
# Caminho do arquivo em PDF:
pdf_path = r"C:\Users\hugob\Dropbox\Hugo_Bovareto\Dissertação PROFIAP\LDA\AM\AM_curriculo_EIEF_com rotacoes.pdf"

# %%
# Função para extração do texto:

def text_extraction(element):
    # Extrair texto:
    line_text = element.get_text()

    # Encontrar o formato do texto:
    # Iniciar a lista com todos os formatos que aparecem nas linhas de texto:
    line_formats = []
    for text_line in element:
        if isinstance(text_line, LTTextContainer):
            # Iterar cada caracter do texto:
            for character in text_line:
                if isinstance(character, LTChar):
                    # Acrescentar o nome da fonte do caracter:
                    line_formats.append(character.fontname)
                    # Acrescentar o tamanho da fonte do caracter:
                    line_formats.append(character.size)
    # Lista de tamanho e nome da fonte dos textos:
    format_per_line = list(set(line_formats))

    # Retornar uma tupla com o texto em cada linha e o seu formato:
    return (line_text, format_per_line)

# %%
# Criar uma função que corta as imagens do PDF:
def crop_image(element, pageObj):
    # Conseguir as coordenados para identificar as imagens no PDF:
    [image_left, image_top, image_right, image_bottom] = [element.x0,element.y0,element.x1,element.y1]
    # Cortar a página usando as coordenadas:
    pageObj.mediabox.lower_left = (image_left, image_bottom)
    pageObj.mediabox.upper_right = (image_right, image_top)
    # Salvar a imagem cortada em um novo arquivo PDF:
    cropped_pdf_writer = PyPDF2.PdfWriter()
    cropped_pdf_writer.add_page(pageObj)
    # Salvar o PDF cortado em um novo arquivo:
    with open('cropped_image.pdf', 'wb') as cropped_pdf_file:
        cropped_pdf_writer.write(cropped_pdf_file)

# Criar uma função para converter o PDF em imagens:
def convert_to_images(input_file,):
    images = convert_from_path(input_file, poppler_path=r'D:\Program Files\poppler-23.11.0\Library\bin')
    image = images[0]
    output_file = "PDF_image.png"
    image.save(output_file, "PNG")

# Criar uma função para ler texto das imagens:
def image_to_text(image_path):
    # Ler a imagem:
    img = Image.open(image_path)
    # Extrair o texto da imagem:
    text = pytesseract.image_to_string(img)
    return text

# %%
# Extrair tabelas de uma página:

def extract_table(pdf_path, page_num, table_num):
    # Abrir o arquivo em PDF:
    pdf = pdfplumber.open(pdf_path)
    # Encontrar a página:
    table_page = pdf.pages[page_num]
    # Extrair as tabelas:
    table = table_page.extract_tables()[table_num]
    return table

# Converter a tabela em formato apropriado:
def table_converter(table):
    table_string = ''
    # Iterar cada linha da tabela:
    for row_num in range(len(table)):
        row = table[row_num]
        # Remover o separador de linhas de textos quebrados:
        cleaned_row = [item.replace('\n', ' ') if item is not None and '\n' in item else 'None' if item is None else item for item in row]
        # Converter uma tabeça em uma strnig:
        table_string+=('|'+'|'.join(cleaned_row)+'|'+'\n')
    # Remover o último separados de linhas:
    table_string = table_string[:-1]
    return table_string

# %%
# Criar um objeto para o arquivo em PDF:
pdfFileObj = open(pdf_path, 'rb')
# Criar um objeto leitor de PDF:
pdfReaded = PyPDF2.PdfReader(pdfFileObj)

# Criar um dicionário para extrair texto de cada imagem:
text_per_page = {}
# Extrair as páginas do PDF:
for pagenum, page in tqdm(enumerate(extract_pages(pdf_path))):

    # Iniciar as variáveis necessárias para extração dos textos de cada página:
    pageObj = pdfReaded.pages[pagenum]
    page_text = []
    line_format = []
    text_from_images = []
    text_from_tables = []
    page_content = []
    # Iniciar o número de tabelas examinadas:
    table_num = 0
    first_element= True
    table_extraction_flag= False
    # Abrir o arquivo em PDF:
    pdf = pdfplumber.open(pdf_path)
    # Encontrar a página examinada:
    page_tables = pdf.pages[pagenum]
    # Encontrar o número de tabelas na página:
    tables = page_tables.find_tables()


    # Encontrar todos os elementos:
    page_elements = [(element.y1, element) for element in page._objs]
    # Classificar os elementos conforme aparecem na página:
    page_elements.sort(key=lambda a: a[0], reverse=True)
    
    lower_side = 0.0
    upper_side = 0.0
    
    # Encontrar os elementos que compõem a página:
    for i,component in enumerate(page_elements):
        # Extrair a posição do elemento:
        pos= component[0]
        # Extrair o elemento do payout da página:
        element = component[1]

        # Checar se o elemento é um texto:
        if isinstance(element, LTTextContainer):
            # Checar se o texto está em uma tabela:
            if table_extraction_flag == False:
                # Extrair o texto e formato de cada elemento textual:
                (line_text, format_per_line) = text_extraction(element)
                # Acrescentar o texto de cada linha:
                page_text.append(line_text)
                # Acrescentar o formato de cada linha contendo texto:
                line_format.append(format_per_line)
                page_content.append(line_text)
            else:
                # Omissão para textos que aparecem em imagens e tabelas:
                pass

        # Checar se o elemento é uma imagem:
        if isinstance(element, LTFigure):
            # Cortar a imagem do arquivo em PDF:
            crop_image(element, pageObj)
            # Converter o PDF cortado em uma imagem:
            convert_to_images('cropped_image.pdf')
            # Extrair o texto da imagem:
            image_text = image_to_text('PDF_image.png')
            text_from_images.append(image_text)
            page_content.append(image_text)
            # Reservar um espaço para lista de textos e formatos:
            page_text.append('image')
            line_format.append('image')

        # Checar os elementos das tabelas:
        if isinstance(element, LTRect):
            # Se o primeiro elementos é retangular:
            if first_element == True and (table_num+1) <= len(tables):
                # Encontrar os limites da tabela:
                lower_side = page.bbox[3] - tables[table_num].bbox[3]
                upper_side = element.y1
                # Extrair as informações da tabela:
                table = extract_table(pdf_path, pagenum, table_num)
                # Converter a informação da tabela em um formato de string:
                table_string = table_converter(table)
                # Adicionar os textos da tabela em uma lista:
                text_from_tables.append(table_string)
                page_content.append(table_string)
                # Definir como 'Verdadeiro' para evitar o conteúdo novamente:
                table_extraction_flag = True
                # Fazer o processo com outro elemento:
                first_element = False
                # Reservar um espaço para lista de textos e formatos:
                page_text.append('table')
                line_format.append('table')

            # Checar se já extraiu as tabelas da página:
            if i + 1 < len(page_elements) and element.y0 >= lower_side and element.y1 <= upper_side:
                pass
            elif i + 1 < len(page_elements) and not isinstance(page_elements[i + 1][1], LTRect):
                table_extraction_flag = False
                first_element = True
                table_num += 1                

    # Criar as páginas como chaves do dicionário:
    dctkey = 'Page_'+str(pagenum)
    # Adicionar as listas como valores para a chave (página do PDF) do dicionário:
    text_per_page[dctkey]= [page_text, line_format, text_from_images,text_from_tables, page_content]
    
# Fechar o objeto do arquivo PDF:
pdfFileObj.close()

# Deletar os arquivos adicionais criados:
os.remove('cropped_image.pdf')
os.remove('PDF_image.png')
# Out:
# 1469it [52:17,  2.14s/it]

# %% [markdown]
# O resultado do processo é armazenado em um dicionário com uma chave para cada página do arquivo PDF e 5 listas para os valores dessa chave. São elas:
# [0] 'page_text': contém o texto proveniente dos elementos de texto do PDF;
#
# [1] 'line_format': comtém os formatos dos textos extraídos no elemento acima;
#
# [2] 'text_from_images': comtém os textos extraídos de imagens;
#
# [3] 'text_from_tables': contém os textos das tabelas;
#
# [4] 'page_content': contém todos os textos renderizados na página em uma lista de elementos.
#
# A última lista ('[4] page_content') é o elemento usado para a análise dos textos aqui, pois possui todos os textos extraídos do PDF.

# %%
# Criar um DataFrame a partir do dicionário com a 5ª lista ('page_content') do Valor:
df = pd.DataFrame({'Chave': list(text_per_page.keys()),
                   'Valor': [valor[4] for valor in text_per_page.values()]})

# Exibir o DataFrame:
df
# Out:
#           Chave                                              Valor
# 0        Page_0  [REFERENCIAL \nCURRICULAR \nAMAZONENSE\n, EDUC...
# 1        Page_1                                                 []
# 2        Page_2  [REFERENCIAL \nCURRICULAR \nAMAZONENSE\n, EDUC...
# 3        Page_3  [MINISTÉRIO DA EDUCAÇÃO \n, Ministro de Estado...
# 4        Page_4  [COMISSÃO DE IMPLEMENTAÇÃO DA BASE NACIONAL CO...
# ...         ...                                                ...
# 1464  Page_1464  [, , LALANDA,  Maria  Conceição;  ABRANTES,  M...
# 1465  Page_1465  [, , MORAN, José. Educação Híbrida: um conceit...
# 1466  Page_1466  [, , PONTE, João. Da formação ao desenvolvimen...
# 1467  Page_1467  [, , toramento em educação, Faculdade de Psico...
# 1468  Page_1468                                    [, , 1\n0\n6\n]
#
# [1469 rows x 2 columns]

# %% [markdown]
# ## 2. Pré-processamento dos dados:

# %% [markdown]
# ### Retirar as páginas que identifiquei que não tem nada de relevante para o conteúdo dos documentos (ex.: sumários, capas, ficha técnica, referências etc):

# %%
# Índices das linhas que você deseja excluir
indices_para_excluir = list(range(0, 18)) + list(range(217, 224)) + list(range(224, 240)) + list(range(854, 867)) + list(range(867, 890)) + list(range(1457, 1469))

# Usando o método drop para excluir as linhas
df = df.drop(indices_para_excluir)

# Reiniciar os índices se necessário
df = df.reset_index(drop=True)

# %%
df
# Out:
#           Chave                                              Valor
# 0       Page_18  [, , Introdução\n, A oferta da Educação Infant...
# 1       Page_19  [, , priam de conhecimentos nas ações e intera...
# 2       Page_20  [, , Fundamental. O Art. 11 das Diretrizes Cur...
# 3       Page_21                                                 []
# 4       Page_22  [, , 1\n, O atual marco regulatório da \nEduca...
# ...         ...                                                ...
# 1375  Page_1452  [, , |ENSINO RELIGIOSO – 7º ANO|None|None|None...
# 1376  Page_1453  [, , 586\n, |ENSINO RELIGIOSO – 8º ANO|None|No...
# 1377  Page_1454  [, , |ENSINO RELIGIOSO – 8º ANO|None|None|None...
# 1378  Page_1455  [, , 588\n, |ENSINO RELIGIOSO – 9º ANO|None|No...
# 1379  Page_1456  [, , |ENSINO RELIGIOSO – 9º ANO|None|None|None...
#
# [1380 rows x 2 columns]

# %%
# Salvar o DataFrame:
import pickle
df.to_pickle("AM_paginas.pkl")

# %% [markdown]
# ### Separação e tokenização das frases:

# %% [markdown]
# As análises serão feitas separando os textos por frases.

# %%
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hugob\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Função para separar as frases de cada página:
def separar_frases(texto):
    return sent_tokenize(texto, language='portuguese')

# %%
# Método apply para aplicar a função em cada linha:
df['frases'] = df['Valor'].astype(str).apply(separar_frases)

# %%
# Expandir cada frase em uma linha e criar um novo dataframe:
df = pd.DataFrame(df['frases'].explode().reset_index(drop=True))

# %% [markdown]
# ### Exclusão de sinalização de parágrafos, sinalização de falta de valor e junção de palavras cortadas entre linhas:

# %%
# Junção de palavras cortadas entre linhas (possuem '-\n' entre a palavra):

df['frases'] = df['frases'].str.replace(r'-\n', '')

# %%
#Exclusão de sinalização de parágrafos (\n):
df['frases'] = df['frases'].str.replace(r'\n', '')

# %%
#Exclusão de sinalização de falta de valor ('None'):
df['frases'] = df['frases'].str.replace(r'None', '')

# %% [markdown]
# ### Pré-processamento:

# %%
# Função para pré-processar o texto:
def preprocessar_texto(texto):
    preprocessado = simple_preprocess(texto, deacc=True, min_len=3, max_len=50)
    return preprocessado

# %%
# Aplicar a função de pré-processamento para criar a nova coluna:
df['Preprocessado'] = df['frases'].apply(preprocessar_texto)

# %%
# Excluir palavras indesejadas:
# "chs" está sendo gerado na identificação das habilidades;

# Função para remover strings específicas das listas:
def remover_string(lista):
    for string_inutil in strings_inuteis:
        if string_inutil in lista:
            lista.remove(string_inutil)
    return lista

strings_inuteis = ["chs"]

# %%
# Aplicar a função à coluna do DataFrame
df['Preprocessado'] = df['Preprocessado'].apply(remover_string)

# %% [markdown]
# ### Remover Stop words:

# %%
# Stop words da biblioteca Spacy:
stopwords_spacy = spacy.lang.pt.stop_words.STOP_WORDS
print('Number of stop words: %d' % len(stopwords_spacy))
# Out:
# Number of stop words: 416

# %%
# Função para remover as stop words:
def remover_stopwords_spacy(texto):
    return [palavra for palavra in texto if palavra not in stopwords_spacy]

# %%
df['Sem_stopwords'] = df['Preprocessado'].apply(remover_stopwords_spacy)

# %% [markdown]
# ### Stemização:

# %% [markdown]
# Há várias opções de stemmers na biblioteca NLTK. Utilizaremos o RSLP que é específico para língua portuguesa.
# (https://www.nltk.org/_modules/nltk/stem/rslp.html; https://dfalbel.github.io/rslp/)

# %%
from nltk.stem import RSLPStemmer

# %%
nltk.download('rslp')
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     C:\Users\hugob\AppData\Roaming\nltk_data...
# [nltk_data]   Package rslp is already up-to-date!
# True

# %%
def stem_RSLPS(tokens):
    stemmer = RSLPStemmer()
    stem_tokens = [stemmer.stem(token) for token in tokens]
    return stem_tokens

# %%
df['Stem'] = df['Sem_stopwords'].apply(stem_RSLPS)

# %%
# Salvar o DataFrame:
df.to_pickle("AM_stem.pkl")

# %% [markdown]
# ## 3. LDA:

# %%
# Criar o dicionário de palavras
dicionario = corpora.Dictionary(df['Stem'])

# %%
# Criar o corpus
corpus = [dicionario.doc2bow(text) for text in df['Stem']]

# %% [markdown]
# ### Identificação do melhor valor para Coherence Score:

# %%
# Função para testar vários coherence scores e perplexities:

def compute_performance(dictionary, corpus, texts, limit, start, step):
    """
    Computa c_v coherence score para vários números de tópicos.

    Parâmetros:
    dicionário: dicionario;
    corpus: corpus;
    texts: lista de listas com as palavras pré-processadas do documento;
    limit: Máximo nº de tópicos;
    start: Nº de tópicos inicial;
    step: intervalo entre os nº de tópicos testados.

    Resultados:
    model_list: lista de modelos LDA.
    coherence_values: valores de coerência correspondentes ao modelo LDA com o respectivo nº de tópicos.
    """
    coherence_values = []
    model_list = []
    perplexity_values = []
    for num_topics in tqdm(range(start, limit, step)):
        model = LdaModel(corpus=corpus,
                         num_topics=num_topics,
                         id2word=dicionario,
                         random_state=42,
                         per_word_topics=True)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        perplexity = model.log_perplexity(corpus)
        perplexity_values.append(perplexity)

    return model_list, coherence_values, perplexity_values

# %%
# Rodar a função (pode levar um tempo elevado):
model_list, coherence_values, perplexity_values = compute_performance(dictionary=dicionario,
                                                                           corpus=corpus,
                                                                           texts=df['Stem'],
                                                                           start=1,
                                                                           limit=102,
                                                                           step=5)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [12:35<00:00, 35.99s/it]

# %%
# Gráfico dos valores de coerência e perplexidade para cada nº de tópicos testado:
limit=102; start=1; step=5;
x = range(start, limit, step)
fig, ax1 = plt.subplots()
color = 'tab:red'
plt.xlabel("Nº de Tópicos")
plt.ylabel("Perplexity score", color=color)
ax1.plot(x, perplexity_values, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx() # 2º eixo que compartilha o mesmo eixo x
color = 'tab:blue'
ax2.set_ylabel('Coherence score', color=color) 
ax2.plot(x, coherence_values, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()

# Salvar imagem:
plt.savefig('AM_Coherence Score_100 topicos.png')

plt.show()

# %%
# Lista dos valores de coerência:
for m, cv, per in zip(x, coherence_values, perplexity_values):
    print("A quantidade de tópicos =", m,
          " tem um valor de coerência de ", round(cv, 4),
          " e valor de perplexidade de", round(per, 4))
# Out:
# A quantidade de tópicos = 1  tem um valor de coerência de  0.5446  e valor de perplexidade de -7.3921
# A quantidade de tópicos = 6  tem um valor de coerência de  0.5072  e valor de perplexidade de -7.4468
# A quantidade de tópicos = 11  tem um valor de coerência de  0.532  e valor de perplexidade de -8.0064
# A quantidade de tópicos = 16  tem um valor de coerência de  0.4519  e valor de perplexidade de -9.2181
# A quantidade de tópicos = 21  tem um valor de coerência de  0.4656  e valor de perplexidade de -9.7787
# A quantidade de tópicos = 26  tem um valor de coerência de  0.4588  e valor de perplexidade de -10.3245
# A quantidade de tópicos = 31  tem um valor de coerência de  0.4163  e valor de perplexidade de -10.9148
# A quantidade de tópicos = 36  tem um valor de coerência de  0.4388  e valor de perplexidade de -11.47
# A quantidade de tópicos = 41  tem um valor de coerência de  0.407  e valor de perplexidade de -12.0402
# A quantidade de tópicos = 46  tem um valor de coerência de  0.4235  e valor de perplexidade de -12.6023
# A quantidade de tópicos = 51  tem um valor de coerência de  0.4415  e valor de perplexidade de -13.1463
# A quantidade de tópicos = 56  tem um valor de coerência de  0.417  e valor de perplexidade de -13.7319
# A quantidade de tópicos = 61  tem um valor de coerência de  0.4227  e valor de perplexidade de -14.2752
# A quantidade de tópicos = 66  tem um valor de coerência de  0.4154  e valor de perplexidade de -14.8465
# A quantidade de tópicos = 71  tem um valor de coerência de  0.4083  e valor de perplexidade de -15.4312
# A quantidade de tópicos = 76  tem um valor de coerência de  0.4078  e valor de perplexidade de -15.9847
# A quantidade de tópicos = 81  tem um valor de coerência de  0.411  e valor de perplexidade de -16.5766
# A quantidade de tópicos = 86  tem um valor de coerência de  0.4079  e valor de perplexidade de -17.11
# A quantidade de tópicos = 91  tem um valor de coerência de  0.4033  e valor de perplexidade de -17.7229
# A quantidade de tópicos = 96  tem um valor de coerência de  0.4125  e valor de perplexidade de -18.3492
# A quantidade de tópicos = 101  tem um valor de coerência de  0.4061  e valor de perplexidade de -18.9047

# %%
# Rodar a função (pode levar um tempo elevado):
model_list, coherence_values, perplexity_values = compute_performance(dictionary=dicionario,
                                                                           corpus=corpus,
                                                                           texts=df['Stem'],
                                                                           start=1,
                                                                           limit=21,
                                                                           step=1)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [11:02<00:00, 33.11s/it]

# %%
# Gráfico dos valores de coerência e perplexidade para cada nº de tópicos testado:
limit=21; start=1; step=1;
x = range(start, limit, step)
fig, ax1 = plt.subplots()
color = 'tab:red'
plt.xlabel("Nº de Tópicos")
plt.ylabel("Perplexity score", color=color)
ax1.plot(x, perplexity_values, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx() # 2º eixo que compartilha o mesmo eixo x
color = 'tab:blue'
ax2.set_ylabel('Coherence score', color=color) 
ax2.plot(x, coherence_values, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()

# Salvar imagem:
plt.savefig('AM_Coherence Score_20 topicos.png')

plt.show()

# %%
# Lista dos valores de coerência:
for m, cv, per in zip(x, coherence_values, perplexity_values):
    print("A quantidade de tópicos =", m,
          " tem um valor de coerência de ", round(cv, 4),
          " e valor de perplexidade de", round(per, 4))
# Out:
# A quantidade de tópicos = 1  tem um valor de coerência de  0.5446  e valor de perplexidade de -7.3921
# A quantidade de tópicos = 2  tem um valor de coerência de  0.5591  e valor de perplexidade de -7.3427
# A quantidade de tópicos = 3  tem um valor de coerência de  0.5494  e valor de perplexidade de -7.3363
# A quantidade de tópicos = 4  tem um valor de coerência de  0.5404  e valor de perplexidade de -7.3545
# A quantidade de tópicos = 5  tem um valor de coerência de  0.5178  e valor de perplexidade de -7.3998
# A quantidade de tópicos = 6  tem um valor de coerência de  0.5072  e valor de perplexidade de -7.4468
# A quantidade de tópicos = 7  tem um valor de coerência de  0.4719  e valor de perplexidade de -7.4711
# A quantidade de tópicos = 8  tem um valor de coerência de  0.5404  e valor de perplexidade de -7.5271
# A quantidade de tópicos = 9  tem um valor de coerência de  0.5132  e valor de perplexidade de -7.6368
# A quantidade de tópicos = 10  tem um valor de coerência de  0.4989  e valor de perplexidade de -7.7877
# A quantidade de tópicos = 11  tem um valor de coerência de  0.532  e valor de perplexidade de -8.0064
# A quantidade de tópicos = 12  tem um valor de coerência de  0.4703  e valor de perplexidade de -8.3288
# A quantidade de tópicos = 13  tem um valor de coerência de  0.4657  e valor de perplexidade de -8.6117
# A quantidade de tópicos = 14  tem um valor de coerência de  0.4925  e valor de perplexidade de -8.8558
# A quantidade de tópicos = 15  tem um valor de coerência de  0.4539  e valor de perplexidade de -9.0917
# A quantidade de tópicos = 16  tem um valor de coerência de  0.4519  e valor de perplexidade de -9.2181
# A quantidade de tópicos = 17  tem um valor de coerência de  0.4704  e valor de perplexidade de -9.3277
# A quantidade de tópicos = 18  tem um valor de coerência de  0.4544  e valor de perplexidade de -9.425
# A quantidade de tópicos = 19  tem um valor de coerência de  0.4474  e valor de perplexidade de -9.5685
# A quantidade de tópicos = 20  tem um valor de coerência de  0.4744  e valor de perplexidade de -9.6766

# %%
# Valor escolhido para coherence score foi 14 tópicos (coherence score = 0.5404):
# Número de tópicos
num_topicos = 8

# %%
# Inputar os dados e rodar o modelo LDA:
modelo_lda = LdaModel(corpus=corpus,
                      id2word=dicionario,
                      num_topics=num_topicos,
                      random_state=42,
                      per_word_topics=True)

# %%
# Imprimir os tópicos:
for topic_id in range(num_topicos):
    print(f"Topic {topic_id}: {modelo_lda.show_topic(topic_id)}")
# Out:
# Topic 0: [('lingu', 0.04205455), ('text', 0.027869407), ('gener', 0.018074824), ('oral', 0.017683718), ('camp', 0.013312924), ('escrit', 0.013125123), ('conhec', 0.012485782), ('leit', 0.011843429), ('ano', 0.011316142), ('objet', 0.011130037)]
# Topic 1: [('espanhol', 0.02993062), ('numer', 0.016273297), ('amazon', 0.009749881), ('utiliz', 0.009036939), ('geometr', 0.008278945), ('pais', 0.007930722), ('med', 0.007848189), ('ment', 0.0076673273), ('lin', 0.0075162193), ('natur', 0.0073856814)]
# Topic 2: [('conhec', 0.036847714), ('objet', 0.026232878), ('ano', 0.021366486), ('habil', 0.016918464), ('competenc', 0.016134929), ('detalh', 0.01529052), ('unidad', 0.014450675), ('pra', 0.013683381), ('tema', 0.013076959), ('ensin', 0.012578996)]
# Topic 3: [('text', 0.057311613), ('produca', 0.02745663), ('leit', 0.018558223), ('soc', 0.01437805), ('gener', 0.01400737), ('argument', 0.012096821), ('escrit', 0.011516332), ('estrut', 0.010773763), ('informaco', 0.010600136), ('context', 0.010142543)]
# Topic 4: [('mund', 0.009701855), ('econom', 0.007900548), ('escol', 0.007269425), ('problem', 0.0072134784), ('difer', 0.007071253), ('linguis', 0.006979323), ('espac', 0.0065982314), ('respeit', 0.0063960045), ('soc', 0.00638089), ('natur', 0.0057740603)]
# Topic 5: [('text', 0.024955768), ('efeit', 0.017931), ('lingu', 0.015208452), ('sent', 0.015045553), ('recurs', 0.014281099), ('verb', 0.013980694), ('discurs', 0.013671559), ('gener', 0.011774849), ('difer', 0.010676502), ('figur', 0.009644062)]
# Topic 6: [('circulaca', 0.020921236), ('music', 0.018294096), ('element', 0.013457426), ('jog', 0.011479461), ('tecn', 0.009980765), ('norm', 0.008376329), ('constitu', 0.0075831097), ('explicit', 0.0071083484), ('popul', 0.006678993), ('ritm', 0.006288277)]
# Topic 7: [('cult', 0.026345845), ('brasil', 0.022674365), ('difer', 0.014255063), ('soc', 0.013022054), ('divers', 0.011208393), ('analis', 0.010352859), ('indigen', 0.009751588), ('religi', 0.009737205), ('art', 0.009458037), ('tecnolog', 0.008820847)]

# %% [markdown]
# ### Visualizações:

# %%
# Visualização dos tópicos:
visualizacao_BNCC = pyLDAvis.gensim_models.prepare(modelo_lda, corpus, dicionario, n_jobs=1)

# %%
# Salvar a visualização como um arquivo HTML:
pyLDAvis.save_html(visualizacao_BNCC, r"AL_visualizacao_BNCC_8_topicos.html")

# %% [markdown]
# ### Distribuição de palavras por frase:

# %%
doc_lens = [len(d) for d in df['Stem']]

# Plot
plt.figure(figsize=(16,7), dpi=160)
plt.hist(doc_lens, bins = 1000, color='navy')
plt.text(180, 500, "Média: " + str(round(np.mean(doc_lens))))
plt.text(180, 480, "Mediana: " + str(round(np.median(doc_lens))))
plt.text(180, 460, "Desvio Padrão: " + str(round(np.std(doc_lens))))
plt.text(180, 440, "Valor mín.: " + str(round(np.min(doc_lens))))
plt.text(180, 420, "1º percentil: " + str(round(np.quantile(doc_lens, q=0.01))))
plt.text(180, 400, "1º quartil: " + str(round(np.quantile(doc_lens, q=0.25))))
plt.text(180, 380, "3º quartil: " + str(round(np.quantile(doc_lens, q=0.75))))
plt.text(180, 360, "99º percentil: " + str(round(np.quantile(doc_lens, q=0.99))))
plt.text(180, 340, "Valor máx.: " + str(round(np.max(doc_lens))))

plt.gca().set(xlim=(0, 230), ylim=(0, 640), ylabel='Número de frases', xlabel='Quantidade de palavras por frase')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,230,9))
plt.yticks(np.linspace(0,640,11))
plt.title('Distribuição de palavras por frase', fontdict=dict(size=22))

# Salvar imagem:
plt.savefig('AM_Distribuicao_de_palavras_por_frase.png')

plt.show()

# %% [markdown]
# ### Frequência de palavras em todo o documento:

# %%
# Concatenar todas as strings em uma única lista de palavras:
palavras = [palavra for lista in df['Stem'].values for palavra in lista]

# Calcular a frequência das palavras:
freq_dist = FreqDist(palavras)

# Obter as palavras mais frequentes:
top30_palavras = freq_dist.most_common(30)

# Criar um DataFrame com as palavras e suas frequências:
top30_palavras_df = pd.DataFrame(top30_palavras, columns=['Palavra', 'Frequência'])

# Imprimir o DataFrame:
top30_palavras_df
# Out:
#       Palavra  Frequência
# 0      conhec        2949
# 1        text        2724
# 2       lingu        2568
# 3       objet        2208
# 4         ano        1945
# 5         pra        1779
# 6        cult        1673
# 7       difer        1640
# 8      crianc        1575
# 9         soc        1514
# 10    educaca        1319
# 11      escol        1297
# 12       leit        1275
# 13      gener        1208
# 14      habil        1185
# 15       camp        1177
# 16      ensin        1104
# 17  competenc        1099
# 18    produca        1003
# 19     escrit        1002
# 20     divers        1000
# 21     detalh         984
# 22       sent         937
# 23      espac         937
# 24  desenvolv         934
# 25    context         911
# 26    process         906
# 27     brasil         906
# 28       tema         857
# 29     profes         852

# %% [markdown]
# "pra" é a raiz de prática.

# %%
# Criar um gráfico de barras com as palavras mais frequentes:
plt.figure(figsize=(16,7), dpi=160)
plt.bar(top30_palavras_df['Palavra'], top30_palavras_df['Frequência'])
plt.title('Palavras mais frequentes', fontdict=dict(size=22))
plt.xlabel('Palavras')
plt.xticks(rotation=45, ha='right')
plt.ylabel('Frequência')

# Salvar imagem:
plt.savefig('AM_Palavras mais frequentes.png')

plt.show()

# %% [markdown]
# ### Nuvem de palavras para todo o documento:

# %%
# Criar uma nuvem de palavras:
wordcloud = WordCloud(width=800, height=400, max_words=100, background_color='white').generate_from_frequencies(freq_dist)
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nuvem de Palavras', fontdict=dict(size=22))

# Salvar imagem:
plt.savefig('AM_Nuvem de palavras_corpus.png')

plt.show()

# %% [markdown]
# ### Frequência de palavras em cada tópico:

# %%
# Criar DataFrame com frequência das palavras no corpus e relevância no tópico:
topics = modelo_lda.show_topics(num_topics=num_topicos, formatted=False)
data_flat = [w for w_list in df['Stem'] for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df_topicos = pd.DataFrame(out, columns=['Stem', 'topic_id', 'relevancia', 'frequencia'])

# %%
# Plotar contagem de palavras e pesos das palavras mais relevantes:
fig, axes = plt.subplots(4, 2, figsize=(16,30), sharey=True, dpi=160)

for i, ax in enumerate(axes.flatten()):
    ax.bar(x='Stem', height="frequencia", data=df_topicos.loc[df_topicos.topic_id==i, :], width=0.5, alpha=0.3, label='Frequência')
    ax_twin = ax.twinx()
    ax_twin.bar(x='Stem', height="relevancia", data=df_topicos.loc[df_topicos.topic_id==i, :], width=0.2, label='Relevância')
    ax.set_ylabel('Frequência')
    ax_twin.set_ylim(0, 0.070); ax.set_ylim(0, 3200)
    ax.set_title('Tópico ' + str(i+1), fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')
    
fig.tight_layout(w_pad=2)    
fig.suptitle('Frequência de palavras e relevância para cada tópico', fontsize=22, y=1.05)

# Salvar imagem:
plt.savefig('AM_Frequencia e relevancia de palavras por topico.png')

plt.show()
# Out:
# C:\Users\hugob\AppData\Local\Temp\ipykernel_24560\134544139.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')
# C:\Users\hugob\AppData\Local\Temp\ipykernel_24560\134544139.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')
# C:\Users\hugob\AppData\Local\Temp\ipykernel_24560\134544139.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')
# C:\Users\hugob\AppData\Local\Temp\ipykernel_24560\134544139.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')
# C:\Users\hugob\AppData\Local\Temp\ipykernel_24560\134544139.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')
# C:\Users\hugob\AppData\Local\Temp\ipykernel_24560\134544139.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')
# C:\Users\hugob\AppData\Local\Temp\ipykernel_24560\134544139.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')
# C:\Users\hugob\AppData\Local\Temp\ipykernel_24560\134544139.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df_topicos.loc[df_topicos.topic_id==i, 'Stem'], rotation=30, horizontalalignment= 'right')

# %% [markdown]
# ### Nuvem de palavras para cada tópico:

# %%
# Configuração do layout dos subplots
num_linhas = 4
num_colunas = 2

# Calcula o número total de subplots necessários
num_subplots = min(num_topicos, num_linhas * num_colunas)

fig, axs = plt.subplots(num_linhas, num_colunas, figsize=(20, 30)) 

for topico_id in range(num_subplots):
    # Obter as palavras e frequências associados ao tópico:
    topico_palavras_pesos = modelo_lda.show_topic(topico_id)
    
    # Criar um dicionário de contagem de palavras e pesos:
    contagem_palavras = {palavra: peso for palavra, peso in topico_palavras_pesos}
    
    # Criar o objeto WordCloud:
    wordcloud = WordCloud(width=400, height=200, background_color='white').generate_from_frequencies(contagem_palavras)
    
    # Adicionar subplot ao layout
    linha = topico_id // num_colunas
    coluna = topico_id % num_colunas
    axs[linha, coluna].imshow(wordcloud, interpolation='bilinear')
    axs[linha, coluna].set_title(f'Tópico {topico_id + 1}', fontdict=dict(size=50))
    axs[linha, coluna].axis('off')

# Colocar o último subplot na última linha entre as duas colunas:
if num_topicos % num_colunas == 1:
    axs[-1, 0].axis('off')  # Desativa os eixos do último subplot na última linha
    axs[-1, 1].remove()     # Remove o último subplot na última linha, segunda coluna
    
# Ajustar o layout para evitar sobreposição
plt.tight_layout()

# Salvar imagem:
plt.savefig('AM_Nuvem de palavras por topico.png')

plt.show()
